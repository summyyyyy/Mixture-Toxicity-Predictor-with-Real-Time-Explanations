# %% [markdown]
# <a href="https://colab.research.google.com/github/summyyyyy/Mixture-Toxicity-Predictor-with-Real-Time-Explanations/blob/Dataset-Preparation/Dataset_Preparation_Toxicity_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DrugComb

# %% [markdown]
# 1. drugcombs_response.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-939164598.py in <cell line: 0>()
#       8 file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'
#       9
# ---> 10 df = pd.read_csv(file_path)
#      11 df_excel = pd.read_excel(file_path_excel)
#      12
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

# %% [markdown]
# 2. drugcombs_scored.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# 3. Syner&Antag_bliss.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# 4. Syner&Antag_hsa.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# 5. Syner&Antag_voting.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# 6. Syner&Antag_zip.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# 7. ThreeDrugCombs.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# 8. yner&Antag_loewe.csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 10 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %% [markdown]
# ---
#
# # SYNERGxDB

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mounts your Google Drive at /content/drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Path/To/Your/Project/Data/mixture_data.csv'

df = pd.read_csv(file_path)
df_excel = pd.read_excel(file_path_excel)

print("--- Data Dimensions ---")
print(f"Number of rows (mixtures): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n--- First 5 Rows ---")
print(df.head(10))
print("\n--- Column Data Types and Non-Null Counts ---")
print(df.info())

# %%
import pandas as pd
import requests
from io import StringIO

# Your OneDrive / SharePoint file path
url = "https://cslw-my.sharepoint.com/:x:/g/personal/nividula_creativesoftware_com/EbenIKWwSexOrs9dbA9WJ_0Bf0amukbTT_2CW9Sv8Kviyw?e=e9cWdu"
# If the link requires login, you need a session with cookies or authentication
# For public access (anyone with link), you can try:
response = requests.get(url)

if response.status_code == 200:
  data = StringIO(response.text)
  print("yes")
  df = pd.read_csv(data)
# print(df.head())
else:
    print("Could not access file. Status code:", response.status_code)
# Out:
# yes
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-4177139977.py in <cell line: 0>()
#      12   data = StringIO(response.text)
#      13   print("yes")
# ---> 14   df = pd.read_csv(data)
#      15 # print(df.head())
#      16 else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 9, saw 5

# %%
import numpy as np
import pandas as pd
# -------------------------------
# Load Tox21 Dataset
# -------------------------------
import kagglehub

# Download the dataset
path = kagglehub.dataset_download("epicskills/tox21-dataset")
print("Dataset path:", path)

# Example: load CSV files (adjust filenames if needed)
# Assuming "tox21.csv" contains columns: "compound_id", "target", "EC50" or "activity"
tox21_df = pd.read_csv(f"{path}/tox21.csv")

# Preview
print(tox21_df.head())
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/epicskills/tox21-dataset?dataset_version_number=1...
# 100%|██████████| 126k/126k [00:00<00:00, 37.1MB/s]
# Extracting files...
# Dataset path: /root/.cache/kagglehub/datasets/epicskills/tox21-dataset/versions/1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1075029825.py in <cell line: 0>()
#      10 # Example: load CSV files (adjust filenames if needed)
#      11 # Assuming "tox21.csv" contains columns: "compound_id", "target", "EC50" or "activity"
# ---> 12 tox21_df = pd.read_csv(f"{path}/tox21.csv")
#      13
#      14 # Preview
#
# NameError: name 'pd' is not defined

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("ComboDrugGrowth_Nov2017.csv")
df.head()
# Out:
#    COMBODRUGSEQ SCREENER                STUDY    TESTDATE        PLATE  \
# 0        260496       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 1        260497       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 2        260498       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 3        260499       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
# 4        260500       FG  PZUT00156_86_01_T72  06/23/2011  786-0_1_T72
#
#    PANELNBR  CELLNBR PREFIX1  NSC1  SAMPLE1  ...  PERCENTGROWTH  \
# 0         9       18       S   752       37  ...         85.979
# 1         9       18       S   752       37  ...        100.903
# 2         9       18       S   752       37  ...         14.147
# 3         9       18       S   752       37  ...         71.268
# 4         9       18       S   752       37  ...         89.278
#
#    PERCENTGROWTHNOTZ TESTVALUE CONTROLVALUE    TZVALUE  EXPECTEDGROWTH  SCORE  \
# 0             88.159  332168.0   376781.548  58592.854          90.342    4.0
# 1            100.763  379656.0   376781.548  58592.854          87.130  -14.0
# 2             27.498  103608.0   376781.548  58592.854          12.739   -1.0
# 3             75.736  285360.0   376781.548  58592.854          76.397    5.0
# 4             90.945  342664.0   376781.548  58592.854          73.681  -16.0
#
#    VALID         PANEL  CELLNAME
# 0      Y  Renal Cancer     786-0
# 1      Y  Renal Cancer     786-0
# 2      Y  Renal Cancer     786-0
# 3      Y  Renal Cancer     786-0
# 4      Y  Renal Cancer     786-0
#
# [5 rows x 29 columns]
# Warning: Total number of columns (29) exceeds max_columns (20) limiting to first (20) columns.

# %%
print(df.columns)
# Out:
# Index(['COMBODRUGSEQ', 'SCREENER', 'STUDY', 'TESTDATE', 'PLATE', 'PANELNBR',
#        'CELLNBR', 'PREFIX1', 'NSC1', 'SAMPLE1', 'CONCINDEX1', 'CONC1',
#        'CONCUNIT1', 'PREFIX2', 'NSC2', 'SAMPLE2', 'CONCINDEX2', 'CONC2',
#        'CONCUNIT2', 'PERCENTGROWTH', 'PERCENTGROWTHNOTZ', 'TESTVALUE',
#        'CONTROLVALUE', 'TZVALUE', 'EXPECTEDGROWTH', 'SCORE', 'VALID', 'PANEL',
#        'CELLNAME'],
#       dtype='object')
